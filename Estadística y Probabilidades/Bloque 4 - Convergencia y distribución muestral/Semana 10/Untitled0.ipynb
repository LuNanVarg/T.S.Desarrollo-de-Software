# %%
#Inicializamos un vector con 7500 columnas
vector = vector(length = 7500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e293ccfcabc0> in <cell line: 0>()
#       1 #Inicializamos un vector con 7500 columnas
# ----> 2 vector = vector(length = 7500)
#
# NameError: name 'vector' is not defined

# %%
from os import replace
muestra=sample(c(1,2,3,4,5,6),7500,replace=T,prob=c(1/6,1/6,1/6,1/6,1/6,1/6))

# %%
#Calculamos la media para un n de 1 a 7500 - n es el tamaño de la muestra:
for(i in 1:7500){
    vector[i]mean(nuestra[1:i])
}
