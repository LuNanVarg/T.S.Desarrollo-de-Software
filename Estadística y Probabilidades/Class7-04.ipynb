# %%
import random as rd
rd.seed(123)
print(rd.random())
print(rd.Random())

rd.seed(1234)
# FOR 1:nrep=1000
# elige 25 personas, chequea coincid y se guarda un 0 o un 1
# Out:
# 0.052363598850944326
# ...
